# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>
#
# # Hands-on Lab: API Examples
# ## Random User and Fruityvice API Examples
#
#
# Estimated time needed: **30** minutes
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Load and use RandomUser API, using `RandomUser()` Python library
# *   Load and use Fruityvice API, using `requests` Python library
# *   Load and use Open-Joke-API, using `requests` Python library

# %% [markdown]
# The purpose of this notebook is to provide more examples on how to use simple APIs. As you have already learned from previous videos and notebooks, API stands for Application Programming Interface and is a software intermediary that allows two applications to talk to each other.
#
# The advantages of using APIs:
#  *   **Automation**. Less human effort is required and workflows can be easily updated to become faster and more
#      productive.
#  *   **Efficiency**. It allows to use the capabilities of one of the already developed APIs than to try to
#      independently implement some functionality from scratch.
#
# The disadvantage of using APIs:
#  *   **Security**. If the API is poorly integrated, it means it will be vulnerable to attacks, resulting in data breeches or losses having financial or reputation implications.
#
# One of the applications we will use in this notebook is Random User Generator. RandomUser is an open-source, free API providing developers with randomly generated users to be used as placeholders for testing purposes. This makes the tool similar to Lorem Ipsum, but is a placeholder for people instead of text. The API can return multiple results, as well as specify generated user details such as gender, email, image, username, address, title, first and last name, and more. More information on [RandomUser](https://randomuser.me/documentation#intro) can be found here.
#
# Another example of simple API we will use in this notebook is Fruityvice application. The Fruityvice API web service which provides data for all kinds of fruit! You can use Fruityvice to find out interesting information about fruit and educate yourself. The web service is completely free to use and contribute to.

# %% [markdown]
# ## Example 1: RandomUser API
# Bellow are Get Methods parameters that we can generate. For more information on the parameters, please visit this [documentation](https://randomuser.me/documentation) page.

# %% [markdown]
# ## **Get Methods**
#
# - get_cell()
# - get_city()
# - get_dob()
# - get_email()
# - get_first_name()
# - get_full_name()
# - get_gender()
# - get_id()
# - get_id_number()
# - get_id_type()
# - get_info()
# - get_last_name()
# - get_login_md5()
# - get_login_salt()
# - get_login_sha1()
# - get_login_sha256()
# - get_nat()
# - get_password()
# - get_phone()
# - get_picture()
# - get_postcode()
# - get_registered()
# - get_state()
# - get_street()
# - get_username()
# - get_zipcode()

# %% [markdown]
# To start using the API you can install the `randomuser` library running the `pip install` command.

# %%
# !pip install randomuser
# !pip install pandas
# Out:
# Collecting randomuser
#   Downloading randomuser-1.6.tar.gz (5.0 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: randomuser
#   Building wheel for randomuser (setup.py) ... one
#   Created wheel for randomuser: filename=randomuser-1.6-py3-none-any.whl size=5104 sha256=188d7260096b73f779914e1a8bfb3218bb9103db51e89986c4ea04c85f0f67cb
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/be/62/c8/71e1b48f4758ea5b78af7595d87178f628cde315a3326610ee
# Successfully built randomuser
# Installing collected packages: randomuser
# Successfully installed randomuser-1.6
# Collecting pandas
#   Downloading pandas-2.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (91 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas) (2024.2)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 144.6 MB/s eta 0:00:00
# Downloading numpy-2.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 163.7 MB/s eta 0:00:00
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: tzdata, numpy, pandas
# Successfully installed numpy-2.3.3 pandas-2.3.2 tzdata-2025.2

# %% [markdown]
# Then, we will load the necessary libraries.

# %%
from randomuser import RandomUser
import pandas as pd

# %% [markdown]
# First, we will create a random user object, r.

# %%
r = RandomUser()
users = r.generate_users(5)
user_data = []
for user in users:
    user_data.append({
        "First Name": user.get_first_name(),
        "Last Name": user.get_last_name(),
        "Email": user.get_email(),
        "Username": user.get_username()
    })

# Convert to a DataFrame for easy viewing
df = pd.DataFrame(user_data)
print(df)
# Out:
#   First Name  Last Name                        Email          Username
# 0      Bruce   Jennings   bruce.jennings@example.com      angryfish868
# 1      Ahmad      Henry      ahmad.henry@example.com  ticklishpanda260
# 2      Murat  Sinanoğlu  murat.sinanoglu@example.com      bluekoala395
# 3     Oliver     Mackay    oliver.mackay@example.com      silvercat822
# 4   Matthieu      Ploum   matthieu.ploum@example.com      smallbird707

# %% [markdown]
# Then, using `generate_users()` function, we get a list of random 10 users.

# %%
users = r.generate_users(5)
user_data = []
for user in users:
    user_data.append({
        "First Name": user.get_first_name(),
        "Last Name": user.get_last_name(),
        "Email": user.get_email(),
        "Username": user.get_username()
    })

# Convert to a DataFrame for easy viewing
df = pd.DataFrame(user_data)
print(df)

# %%
users
# Out:
# [<randomuser.RandomUser at 0x7843a6da68a0>,
#  <randomuser.RandomUser at 0x7843a6da68d0>,
#  <randomuser.RandomUser at 0x7843a6da6900>,
#  <randomuser.RandomUser at 0x7843a6da6930>,
#  <randomuser.RandomUser at 0x7843a6da6960>]

# %% [markdown]
# The **"Get Methods"** functions mentioned at the beginning of this notebook, can generate the required parameters to construct a dataset. For example, to get full name, we call `get_full_name()` function.

# %%
name = r.get_full_name()

# %% [markdown]
# Let's say we only need 10 users with full names and their email addresses. We can write a "for-loop" to print these 10 users.

# %%
for user in some_list:
    print (user.get_full_name()," ",user.get_email())
# Out:
# Luke Thompson   luke.thompson@example.com
# Betina Boden   betina.boden@example.com
# Mathilde Kristensen   mathilde.kristensen@example.com
# Hector Calvo   hector.calvo@example.com
# Mia Hernandez   mia.hernandez@example.com
# Mira Araújo   mira.araujo@example.com
# Madelene Kalleberg   madelene.kalleberg@example.com
# Deniz Ekici   deniz.ekici@example.com
# Josias Silva   josias.silva@example.com
# Nora Palmer   nora.palmer@example.com

# %% [markdown]
# ## Exercise 1
# In this Exercise, generate photos of the random 10 users.

# %%
## Write your code here
from randomuser import RandomUser
import pandas as pd

# Generate 5 random users
r = RandomUser()
users = r.generate_users(5)

# Extract user data including profile pictures
user_data = []
for user in users:
    user_data.append({
        "First Name": user.get_first_name(),
        "Last Name": user.get_last_name(),
        "Email": user.get_email(),
        "Username": user.get_username(),
        "Picture": user.get_picture()
    })

# Convert to DataFrame
df = pd.DataFrame(user_data)
print(df)

# Display profile pictures (if using Jupyter Notebook or similar)
from IPython.display import Image, display

for pic_url in df["Picture"]:
    display(Image(url=pic_url))
# Out:
#   First Name Last Name                        Email        Username  \
# 0        Joe     Meyer        joe.meyer@example.com    crazyfish546
# 1       Leah     Silva       leah.silva@example.com  blueostrich209
# 2       Önal  Küçükler    onal.kucukler@example.com    greenduck856
# 3   Calogero    Ritter  calogero.ritter@example.com    greenbear625
# 4    Zakaria   Vadseth  zakaria.vadseth@example.com  lazymeercat199
#
#                                             Picture
# 0    https://randomuser.me/api/portraits/men/58.jpg
# 1  https://randomuser.me/api/portraits/women/43.jpg
# 2    https://randomuser.me/api/portraits/men/91.jpg
# 3    https://randomuser.me/api/portraits/men/17.jpg
# 4    https://randomuser.me/api/portraits/men/25.jpg
# <img src="https://randomuser.me/api/portraits/men/58.jpg"/>
# <img src="https://randomuser.me/api/portraits/women/43.jpg"/>
# <img src="https://randomuser.me/api/portraits/men/91.jpg"/>
# <img src="https://randomuser.me/api/portraits/men/17.jpg"/>
# <img src="https://randomuser.me/api/portraits/men/25.jpg"/>

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# for user in some_list:
#     print (user.get_picture())
# ```
#
# </details>

# %% [markdown]
# To generate a table with information about the users, we can write a function containing all desirable parameters. For example, name, gender, city, etc. The parameters will depend on the requirements of the test to be performed. We call the Get Methods, listed at the beginning of this notebook. Then, we return pandas dataframe with the users.

# %%
for user in some_list:
    print (user.get_picture())
    from IPython.display import Image, display

for pic_url in df["Picture"]:
    display(Image(url=pic_url))
# Out:
# https://randomuser.me/api/portraits/men/91.jpg
# https://randomuser.me/api/portraits/women/84.jpg
# https://randomuser.me/api/portraits/women/0.jpg
# https://randomuser.me/api/portraits/men/44.jpg
# https://randomuser.me/api/portraits/women/32.jpg
# https://randomuser.me/api/portraits/women/8.jpg
# https://randomuser.me/api/portraits/women/96.jpg
# https://randomuser.me/api/portraits/women/42.jpg
# https://randomuser.me/api/portraits/men/15.jpg
# https://randomuser.me/api/portraits/women/2.jpg
# <img src="https://randomuser.me/api/portraits/men/58.jpg"/>
# <img src="https://randomuser.me/api/portraits/women/43.jpg"/>
# <img src="https://randomuser.me/api/portraits/men/91.jpg"/>
# <img src="https://randomuser.me/api/portraits/men/17.jpg"/>
# <img src="https://randomuser.me/api/portraits/men/25.jpg"/>

# %%
get_users()
# Out:
#              Name  Gender        City             State  \
# 0   Polda Ribeiro  female       Crato    Espírito Santo
# 1    Irânia Alves  female     Birigüi  Distrito Federal
# 2      Alice King  female   Masterton          Gisborne
# 3    آراد نكو نظر    male      ارومیه             همدان
# 4  Olivia Pietila  female  Lestijärvi   Central Finland
# 5     Freya Kumar  female    Hastings            Tasman
# 6  Lillie Lambert  female      Pueblo          Kentucky
# 7    Freya Turner  female    Blenheim          Taranaki
# 8  Dwight Holland    male  High Point            Hawaii
# 9  Gül Tekelioğlu  female   Kastamonu           Karaman
#
#                         Email                       DOB  \
# 0   polda.ribeiro@example.com  1998-09-21T11:45:47.759Z
# 1    irania.alves@example.com  1993-06-22T12:20:12.556Z
# 2      alice.king@example.com  1973-10-29T20:38:22.426Z
# 3      ard.nkwnzr@example.com  1966-06-03T18:55:24.512Z
# 4  olivia.pietila@example.com  1980-11-07T04:28:55.601Z
# 5     freya.kumar@example.com  1991-11-17T08:17:17.679Z
# 6  lillie.lambert@example.com  1994-12-25T09:38:19.016Z
# 7    freya.turner@example.com  1972-03-27T23:51:36.399Z
# 8  dwight.holland@example.com  1984-12-27T06:36:43.866Z
# 9  gul.tekelioglu@example.com  1958-01-24T20:44:14.457Z
#
#                                             Picture
# 0  https://randomuser.me/api/portraits/women/13.jpg
# 1  https://randomuser.me/api/portraits/women/10.jpg
# 2  https://randomuser.me/api/portraits/women/87.jpg
# 3    https://randomuser.me/api/portraits/men/71.jpg
# 4  https://randomuser.me/api/portraits/women/91.jpg
# 5  https://randomuser.me/api/portraits/women/36.jpg
# 6  https://randomuser.me/api/portraits/women/96.jpg
# 7  https://randomuser.me/api/portraits/women/66.jpg
# 8    https://randomuser.me/api/portraits/men/86.jpg
# 9  https://randomuser.me/api/portraits/women/83.jpg

# %%
df1 = pd.DataFrame(get_users())

# %% [markdown]
# Now we have a *pandas* dataframe that can be used for any testing purposes that the tester might have.

# %% [markdown]
# ## Example 2: Fruityvice API
#
# Another, more common way to use APIs, is through `requests` library. The next lab, Requests and HTTP, will contain more information about requests.
#
# We will start by importing all required libraries.

# %%
import requests
import json

# %% [markdown]
# We will obtain the [fruityvice](https://www.fruityvice.com) API data using `requests.get("url")` function. The data is in a json format.

# %%
import requests

# Fetch data from the archived API endpoint
data = requests.get("https://web.archive.org/web/20240929211114/https://fruityvice.com/api/fruit/all")

# %% [markdown]
# We will retrieve results using `json.loads()` function.

# %%
results = json.loads(data.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 results = json.loads(data.text)
#
# NameError: name 'json' is not defined

# %% [markdown]
# We will convert our json data into *pandas* data frame.

# %%
pd.DataFrame(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 pd.DataFrame(results)
#
# NameError: name 'results' is not defined

# %% [markdown]
# The result is in a nested json format. The 'nutrition' column contains multiple subcolumns, so the data needs to be 'flattened' or normalized.

# %%
df2 = pd.json_normalize(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df2 = pd.json_normalize(results)
#
# NameError: name 'results' is not defined

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df2
#
# NameError: name 'df2' is not defined

# %% [markdown]
# Let's see if we can extract some information from this dataframe. Perhaps, we need to know the family and genus of a cherry.

# %%
cherry = df2.loc[df2["name"] == 'Cherry']
(cherry.iloc[0]['family']) , (cherry.iloc[0]['genus'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 cherry = df2.loc[df2["name"] == 'Cherry']
#       2 (cherry.iloc[0]['family']) , (cherry.iloc[0]['genus'])
#
# NameError: name 'df2' is not defined

# %% [markdown]
# ## Exercise 2
# In this Exercise, find out how many calories are contained in a banana.

# %%
# Write your code here
import requests
import pandas as pd

# Fetch the fruit data from the archived API
response = requests.get("https://web.archive.org/web/20240929211114/https://fruityvice.com/api/fruit/all")

# Convert JSON response to a DataFrame
fruit_list = response.json()
df2 = pd.DataFrame(fruit_list)

# Normalize the 'nutritions' dictionary into separate columns
nutritions_df = pd.json_normalize(df2['nutritions'])
df2 = pd.concat([df2.drop(columns=['nutritions']), nutritions_df], axis=1)

# Now filter for banana and get its calorie count
banana = df2.loc[df2["name"] == "Banana"]
calories = banana.iloc[0]["calories"]

print("Calories in a banana:", calories)
# Out:
# Calories in a banana: 96

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# cal_banana = df2.loc[df2["name"] == 'Banana']
# cal_banana.iloc[0]['nutritions.calories']
# ```
#
# </details>

# %% [markdown]
# ## Exercise 3
#
# This [page](https://mixedanalytics.com/blog/list-actually-free-open-no-auth-needed-apis/) contains a list of free public APIs for you to practice. Let us deal with the following example.
#
# #### Official Joke API
# This API returns random jokes from a database. The following URL can be used to retrieve 10 random jokes.
#
# https://official-joke-api.appspot.com/jokes/ten
#
# 1. Using `requests.get("url")` function, load the data from the URL.

# %%
# Write your code here
import requests
url = "https://official-joke-api.appspot.com/jokes/ten"
response = requests.get(url)
jokes = response.json()
for joke in jokes:
    print(f"{joke['setup']} - {joke['punchline']}\n")
# Out:
# What do you call a fat psychic? - A four-chin teller.
#
# Why did the coffee file a police report? - It got mugged.
#
# Why do bees have sticky hair? - Because they use honey combs!
#
# Do you know where you can get chicken broth in bulk? - The stock market.
#
# What do you give a sick lemon? - Lemonaid.
#
# Why do trees seem suspicious on sunny days? - Dunno, they're just a bit shady.
#
# How does a scientist freshen their breath? - With experi-mints!
#
# What’s the object-oriented way to become wealthy? - Inheritance.
#
# Why did the fireman wear red, white, and blue suspenders? - To hold his pants up.
#
# Why did the programmer's wife leave him? - He didn't know how to commit.

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# data2 = requests.get("https://official-joke-api.appspot.com/jokes/ten")
# ```
#
# </details>

# %% [markdown]
# 2. Retrieve results using `json.loads()` function.

# %%
# Write your code here

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# results2 = json.loads(data2.text)
# ```
#
# </details>

# %% [markdown]
# 3. Convert json data into *pandas* data frame. Drop the type and id columns.

# %%
# Write your code here
import requests
import json

# Step 1: Send a GET request to the API
url = "https://official-joke-api.appspot.com/jokes/ten"
response = requests.get(url)

# Step 2: Get the raw JSON string from the response
json_string = response.text

# Step 3: Parse the JSON string into a Python object
jokes = json.loads(json_string)

# Step 4: Display the jokes
for joke in jokes:
    print(f"{joke['setup']} - {joke['punchline']}\n")


    df3 = pd.DataFrame(results2)
df3.drop(columns=["type","id"],inplace=True)
df3
# Out:
# Why does Superman get invited to dinners? - Because he is a Supperhero.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 20
#      16 for joke in jokes:
#      17     print(f"{joke['setup']} - {joke['punchline']}\n")
# ---> 20     df3 = pd.DataFrame(results2)
#      21 df3.drop(columns=["type","id"],inplace=True)
#      22 df3
#
# NameError: name 'results2' is not defined

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df3 = pd.DataFrame(results2)
# df3.drop(columns=["type","id"],inplace=True)
# df3
# ```
#
# </details>

# %% [markdown]
# # Congratulations! - You have completed the lab

# %% [markdown]
# ## Author
# <a href="https://www.linkedin.com/in/svitlana-kramar" target="_blank">Svitlana Kramar</a>
#
# Svitlana is a master’s degree Data Science and Analytics student at University of Calgary, who enjoys travelling, learning new languages and cultures and loves spreading her passion for Data Science.
#
# ## Additional Contributor
# <a href="https://www.linkedin.com/in/abhishek-gagneja-23051987/" target="_blank">Abhishek Gagneja</a>

# %% [markdown]
# Copyright © 2023 IBM Corporation. All rights reserved.
